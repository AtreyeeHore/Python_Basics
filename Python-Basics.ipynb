# %% [markdown]
# 1.Explain the key features of Python that make it a popular choice for programming?
#
# Simple and Readable Syntax
# Python syntax is clean and close to English, making it easy to read and write.
# Ideal for beginners and reduces the learning curve for new programmers.
#
# 🔑 2. Interpreted Language
# Code is executed line-by-line by the Python interpreter.
#
# No need to compile, which speeds up development and testing.
#
# 🔑 3. Dynamically Typed
# You don't need to declare variable types explicitly.
#
# Python automatically identifies the type at runtime.
#
# 🔑 4. Versatile and General-Purpose
# Used in web development, data science, automation, artificial intelligence, game development, and more.
#
# 🔑 5. Extensive Standard Library
# Comes with a large collection of built-in modules and packages for common tasks like file handling, networking, and math.

# %% [markdown]
# 2.Describe the role of predefined keywords in Python and provide examples of how they are used in a
# program.
#
# -Predefined keywords in Python are reserved words that have special meanings and are part of the syntax of the language. You cannot use them as variable names, function names, or identifiers because Python uses them to define the structure and rules of the language.

# %%
x = 10
if x > 0:
    print("Positive")
elif x == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Positive

# %% [markdown]
# 3.Compare and contrast mutable and immutable objects in Python with examples.
#
# ✅ Mutable objects: Can be changed after they are created.
#
# ❌ Immutable objects: Cannot be changed once created.

# %% [markdown]
# 4.Discuss the different types of operators in Python and provide examples of how they are used.
#
# 1. Arithmetic Operators
# Used for basic mathematical operations.
#
# 2. Assignment Operators
# Used to assign values to variables.
#
# 3. Comparison Operators
# Used to compare two values and return True or False.
#
# 4. Logical Operators
# Used to combine conditional statements.
#
# 5. Bitwise Operators
# Used to perform bit-level operations.
#
# 6. Identity Operators
# Used to compare memory locations of two objects.

# %% [markdown]
# 5. Explain the concept of type casting in Python with examples.
#
# Type casting (or type conversion) in Python refers to converting one data type into another. This is useful when you're working with mixed types (e.g., numbers and strings) and want to perform operations that require matching types.
#
# Two Types of Type Casting
#
#
# i.Implicit Type Casting
# Python automatically converts one data type to another when needed.
#
#
# ii.Explicit Type Casting
# The programmer manually converts one data type to another using built-in functions.

# %%
a = 5        # int
b = 2.0      # float
c = a + b    # int + float = float

print(c)        # 7.0
print(type(c))  # <class 'float'>

# %%
x = "10"
y = int(x)    # string to integer
print(y + 5)  # 15

# %% [markdown]
# 6.How do conditional statements work in Python? Illustrate with examples.
#
# Conditional statements allow a Python program to make decisions and execute specific blocks of code depending on whether a condition is True or False.

# %%
marks = 75

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
else:
    print("Grade: F")

# %% [markdown]
# 7.Describe the different types of loops in Python and their use cases with examples.
#
# Types of Loops in Python:
#
# for loop
#
# while loop
#
# Nested loops
#
# Loop control statements: break, continue, pass
